# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_excel('NNI Data.xlsx')
df.head()
# Out:
#    link_name_id                  client_name             link_id vlan_id  \
# 0           421                 Agni Systems   agni_080217_02_nb    2404
# 1           439  Cosmopolitan Communications   cpcl_230517_01_nb    2937
# 2           447                           GP  gmpn_280713_011_nd       0
# 3           473  Cosmopolitan Communications   cpcl_230517_04_nb    2940
# 4           477          ICOM Bangladesh Ltd   icom_280616_09_ib    2267
#
#   link_category link_conn_type district district_secondary  \
# 0        Access             TX    Dhaka          Madaripur
# 1      Capacity             OH    Dhaka              Dhaka
# 2        Access             OH    Dhaka              Dhaka
# 3      Capacity             OH    Dhaka              Dhaka
# 4      Capacity             TX    Dhaka              Dhaka
#
#                                    region       sms_group  ...  \
# 0  Regional Implementation & Operations 3              29  ...
# ...
